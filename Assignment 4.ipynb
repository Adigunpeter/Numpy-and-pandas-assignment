# %% [markdown]
# #import the car_price dataset #extract all the values that is not null from the dataset to a new variable #extract all the null vauee from the dataset into a new variable #drop all columns containing null values from the original dataset #clean the dataset so it deosn't have any null value again #compute the sum, mean of the price column on the dataset #get the car with the lowest price and with the highest price

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = pd.read_csv('carprice.csv', encoding = "ISO-8859-1")
dataset
# Out:
# C:\Users\oluwa\AppData\Local\Temp\ipykernel_1140\949109088.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv('carprice.csv', encoding = "ISO-8859-1")
#              dateCrawled                                          name  \
# 0       24/03/2016 11:52                                    Golf_3_1.6
# 1       24/03/2016 10:58                          A5_Sportback_2.7_Tdi
# 2       14/03/2016 12:52                Jeep_Grand_Cherokee_"Overland"
# 3       17/03/2016 16:54                            GOLF_4_1_4__3TÜRER
# 4       31/03/2016 17:25                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                  ...                                           ...
# 371534  14/03/2016 17:48                    Suche_t4___vito_ab_6_sitze
# 371535  05/03/2016 19:56         Smart_smart_leistungssteigerung_100ps
# 371536  19/03/2016 18:57            Volkswagen_Multivan_T4_TDI_7DC_UY2
# ...

# %%
dataset
# Out:
#              dateCrawled                                          name  \
# 0       24/03/2016 11:52                                    Golf_3_1.6
# 1       24/03/2016 10:58                          A5_Sportback_2.7_Tdi
# 2       14/03/2016 12:52                Jeep_Grand_Cherokee_"Overland"
# 3       17/03/2016 16:54                            GOLF_4_1_4__3TÜRER
# 4       31/03/2016 17:25                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                  ...                                           ...
# 371534  14/03/2016 17:48                    Suche_t4___vito_ab_6_sitze
# 371535  05/03/2016 19:56         Smart_smart_leistungssteigerung_100ps
# 371536  19/03/2016 18:57            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371537  20/03/2016 19:41                        VW_Golf_Kombi_1_9l_TDI
# 371538  07/03/2016 19:39  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType    price   abtest vehicleType  yearOfRegistration  \
# ...

# %%
dataset_null = dataset[dataset.isnull()]
dataset_null
# Out:
#        dateCrawled name seller offerType  price abtest vehicleType  \
# 0              NaN  NaN    NaN       NaN    NaN    NaN         NaN
# 1              NaN  NaN    NaN       NaN    NaN    NaN         NaN
# 2              NaN  NaN    NaN       NaN    NaN    NaN         NaN
# 3              NaN  NaN    NaN       NaN    NaN    NaN         NaN
# 4              NaN  NaN    NaN       NaN    NaN    NaN         NaN
# ...            ...  ...    ...       ...    ...    ...         ...
# 371534         NaN  NaN    NaN       NaN    NaN    NaN         NaN
# 371535         NaN  NaN    NaN       NaN    NaN    NaN         NaN
# 371536         NaN  NaN    NaN       NaN    NaN    NaN         NaN
# 371537         NaN  NaN    NaN       NaN    NaN    NaN         NaN
# 371538         NaN  NaN    NaN       NaN    NaN    NaN         NaN
#
#         yearOfRegistration gearbox  powerPS model kilometer  \
# 0                      NaN     NaN      NaN   NaN       NaN
# ...

# %%
dataset_notnull = dataset[dataset.notnull()]
dataset_notnull
# Out:
#              dateCrawled                                          name  \
# 0       24/03/2016 11:52                                    Golf_3_1.6
# 1       24/03/2016 10:58                          A5_Sportback_2.7_Tdi
# 2       14/03/2016 12:52                Jeep_Grand_Cherokee_"Overland"
# 3       17/03/2016 16:54                            GOLF_4_1_4__3TÜRER
# 4       31/03/2016 17:25                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                  ...                                           ...
# 371534  14/03/2016 17:48                    Suche_t4___vito_ab_6_sitze
# 371535  05/03/2016 19:56         Smart_smart_leistungssteigerung_100ps
# 371536  19/03/2016 18:57            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371537  20/03/2016 19:41                        VW_Golf_Kombi_1_9l_TDI
# 371538  07/03/2016 19:39  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType    price   abtest vehicleType  yearOfRegistration  \
# ...

# %% [markdown]
# #import the car_price dataset #extract all the values that is not null from the dataset to a new variable #extract all the null vauee from the dataset into a new variable #drop all columns containing null values from the original dataset #clean the dataset so it deosn't have any null value again #compute the sum, mean of the price column on the dataset #get the car with the lowest price and with the highest price

# %%
dataset.dropna(axis = 'columns', how = 'all').isnull()
# Out:
#         dateCrawled   name  seller  offerType  price  abtest  vehicleType  \
# 0             False  False   False      False  False   False         True
# 1             False  False   False      False  False   False        False
# 2             False  False   False      False  False   False        False
# 3             False  False   False      False  False   False        False
# 4             False  False   False      False  False   False        False
# ...             ...    ...     ...        ...    ...     ...          ...
# 371534        False  False   False      False  False   False         True
# 371535        False  False   False      False  False   False        False
# 371536        False  False   False      False  False   False        False
# 371537        False  False   False      False  False   False        False
# 371538        False  False   False      False  False   False        False
#
#         yearOfRegistration  gearbox  powerPS  model  kilometer  \
# ...

# %%
price = dataset['price']
np.mean(price)
# Out:
# 17295.439494748854

# %%
price = dataset['price']
np.sum(price)
# Out:
# 6425912999.0

# %%
#dataset = dataset.set_index('name')
dataset
# Out:
#              dateCrawled                                          name  \
# 0       24/03/2016 11:52                                    Golf_3_1.6
# 1       24/03/2016 10:58                          A5_Sportback_2.7_Tdi
# 2       14/03/2016 12:52                Jeep_Grand_Cherokee_"Overland"
# 3       17/03/2016 16:54                            GOLF_4_1_4__3TÜRER
# 4       31/03/2016 17:25                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                  ...                                           ...
# 371534  14/03/2016 17:48                    Suche_t4___vito_ab_6_sitze
# 371535  05/03/2016 19:56         Smart_smart_leistungssteigerung_100ps
# 371536  19/03/2016 18:57            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371537  20/03/2016 19:41                        VW_Golf_Kombi_1_9l_TDI
# 371538  07/03/2016 19:39  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType    price   abtest vehicleType  yearOfRegistration  \
# ...

# %%
# return president with maximum height
#pres_name[pres_height.argmax()]
# pres_height.argmax()
# pres_name[15]

# %%
price = dataset['price']
price.argmax()
dataset.iloc[129969]['name']
# Out:
# 'Kaufe_AUTOS_Zum_basteln'

# %%
price = dataset['price']
price.argmin()
dataset.iloc[7]['name']
# Out:
# 'VW_Derby_Bj_80__Scheunenfund'

# %% [markdown]
# # Another Method to find the car with the highest and lowest price

# %%
name = dataset['name']
price = dataset['price']
name[price.argmax()]
# Out:
# 'Kaufe_AUTOS_Zum_basteln'

# %%
name = dataset['name']
price = dataset['price']
name[price.argmin()]
# Out:
# 'VW_Derby_Bj_80__Scheunenfund'
